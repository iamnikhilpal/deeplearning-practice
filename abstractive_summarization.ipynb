# %% [markdown]
# <a href="https://colab.research.google.com/github/iamnikhilpal/deeplearning-practice/blob/main/abstractive_summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 85.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 87.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 76.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 93.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 85.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 52.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 103.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.1+cu116
#     Uninstalling torchaudio-0.13.1+cu116:
#       Successfully uninstalled torchaudio-0.13.1+cu116
# ...

# %%
# !pip3 install sentencepiece transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer

# %%
tokenizer = PegasusTokenizer.from_pretrained("google/pegasus-xsum")

# %%
# load a model
model = PegasusForConditionalGeneration.from_pretrained("google/pegasus-xsum")

# %%
# Perform aabstractive summarization
text = """
There are several existing pretrained text summarization models that are publicly available and can be used for various natural language processing tasks. Here are some of the most popular ones:

BART (Facebook AI Research): Bidirectional and Auto-Regressive Transformer model that is trained on large amounts of text data. It has achieved state-of-the-art results on several text summarization tasks.

T5 (Google AI): Transformer-based Text-To-Text Transfer Transformer model that is trained on a wide range of NLP tasks, including summarization. It has achieved state-of-the-art results on several text summarization benchmarks.

PEGASUS (Google Research): Pre-training with Extracted Gap-sentences for Abstractive SUmmarization Sequence-to-sequence model that is trained on massive amounts of text data. It has achieved state-of-the-art results on several text summarization benchmarks.

GPT-2 (OpenAI): Generative Pretrained Transformer model that is trained on a large amount of text data. It has been used for text generation and text summarization tasks and has achieved state-of-the-art results on several text summarization benchmarks.

XSUM (University of Edinburgh): Transformer-based model that is trained specifically for single-document summarization. It has achieved state-of-the-art results on the XSum dataset, which is a popular benchmark for summarization.

These models are available for download and can be used for a wide range of summarization tasks, including news article summarization, scientific paper summarization, and document summarization.
"""

# %%
text_1 = """
Police said that the arrests were made for defacing public property and under the law that requires posters to have the name of the printing press. Delhi police said that they registered 138 FIRs on Tuesday, out of which 36 were for anti-Modi posters.

Some 2,000 posters, which were allegedly being delivered to the Aam Aadmi Party (AAP)'s office, were seized by the police. Cops found the posters when they intercepted a van in the IP Estate area in Central Delhi. The driver told police that he had been instructed to deliver the posters to the AAP headquarters.

He said that he had delivered a similar consignment on Monday too.

The Aam Aadmi Party, in a tweet, questioned the FIRs and asked what was objectionable in the posters. The party also said that this was the
"""

# %%
# step text -> token
# tokens = tokenizer(text, truncation=True, padding="longest", return_tensors="pt")
tokens = tokenizer(text_1, truncation=True, padding="longest", return_tensors="pt")

# %%
tokens
# Out:
# {'input_ids': tensor([[ 3385,   243,   120,   109, 21921,   195,   266,   118,   718, 15285,
#            481,   593,   111,   365,   109,   775,   120,  1632,  9106,   112,
#            133,   109,   442,   113,   109,  3435,  1833,   107,  5321,  1564,
#            243,   120,   157,  2451, 25449, 48643,   116,   124,  1842,   108,
#            165,   113,   162,  4335,   195,   118,  1857,   121, 84021,  9106,
#            107,  1027,  9717,  9106,   108,   162,   195,  9614,   270,  2336,
#            112,   109,   202,  1524,   202, 64798,  2905,   143, 59509,   158,
#            131,   116,   629,   108,   195, 15924,   141,   109,  1564,   107,
#          26943,   116,   374,   109,  9106,   173,   157, 37999,   114,  4406,
#            115,   109,  3276,  4411,   345,   115,  2178,  5321,   107,   139,
#           1712,   898,  1564,   120,   178,   196,   174, 14813,   112,  1511,
#            109,  9106,   112,   109, 44874,  7243,   107,   285,   243,   120,
# ...

# %%
# summarize
summary = model.generate(**tokens)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (64) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
summary
# Out:
# tensor([[    0,  1439,   197,  1061,   200,   133,   174,  5283,   115,  5321,
#            118,  9614, 17452,  9106,   464,  4230,  2965, 29839, 14349,   107,
#              1]])

# %%
tokenizer.decode(summary[0])
# Out:
# '<pad>More than 100 people have been arrested in Delhi for allegedly distributing posters against Prime Minister Narendra Modi.</s>'
