# %%
# House movement in G7 countries

# %%
# Libraries
import pandas_datareader as pdr
import pandas as pd
import requests
import plotly.express as px
from datetime import datetime

# %%
# data reader
def get_data(series_list, start_date, end_date):
  df = pdr.DataReader(series_list,'fred',start_date, end_date)
  return df.reset_index()

series = 'QCAR628BIS'

df_canada = get_data(series_list=[series], start_date='1970-01-01', end_date='2021-10-01')

# %%
df_canada
# Out:
#           DATE  QCAR628BIS
# 0   1970-01-01     37.8580
# 1   1970-04-01     37.6715
# 2   1970-07-01     37.6729
# 3   1970-10-01     38.9418
# 4   1971-01-01     39.0597
# ..         ...         ...
# 203 2020-10-01    165.7664
# 204 2021-01-01    168.1633
# 205 2021-04-01    176.8375
# 206 2021-07-01    178.5126
# 207 2021-10-01    180.3430
#
# [208 rows x 2 columns]

# %%
fig = px.line(df_canada, x="DATE", y="QCAR628BIS", title="Real Residential Property prices for canada.")
fig.update_layout(title=dict(x=0.5, y=0.95))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="af0c56d4-5b24-4c1f-a0e4-e3bdd3569494" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af0c56d4-5b24-4c1f-a0e4-e3bdd3569494")) {                    Plotly.newPlot(                        "af0c56d4-5b24-4c1f-a0e4-e3bdd3569494",                        [{"hovertemplate":"DATE=%{x}\u003cbr\u003eQCAR628BIS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1970-01-01T00:00:00","1970-04-01T00:00:00","1970-07-01T00:00:00","1970-10-01T00:00:00","1971-01-01T00:00:00","1971-04-01T00:00:00","1971-07-01T00:00:00","1971-10-01T00:00:00","1972-01-01T00:00:00","1972-04-01T00:00:00","1972-07-01T00:00:00","1972-10-01T00:00:00","1973-01-01T00:00:00","1973-04-01T00:00:00","1973-07-01T00:00:00","1973-10-01T00:00:00","1974-01-01T00:00:00","1974-04-01T00:00:00","1974-07-01T00:00:00","1974-10-01T00:00:00","1975-01-01T00:00:00","1975-04-01T00:00:00","1975-07-01T00:00:00","1975-10-01T00:00:00","1976-01-01T00:00:00","1976-04-01T00:00:00","1976-07-01T00:00:00","1976-10-01T00:00:00","1977-01-01T00:00:00","1977-04-01T00:00:00","1977-07-01T00:00:00","1977-10-01T00:00:00","1978-01-01T00:00:00","1978-04-01T00:00:00","1978-07-01T00:00:00","1978-10-01T00:00:00","1979-01-01T00:00:00","1979-04-01T00:00:00","1979-07-01T00:00:00","1979-10-01T00:00:00","1980-01-01T00:00:00","1980-04-01T00:00:00","1980-07-01T00:00:00","1980-10-01T00:00:00","1981-01-01T00:00:00","1981-04-01T00:00:00","1981-07-01T00:00:00","1981-10-01T00:00:00","1982-01-01T00:00:00","1982-04-01T00:00:00","1982-07-01T00:00:00","1982-10-01T00:00:00","1983-01-01T00:00:00","1983-04-01T00:00:00","1983-07-01T00:00:00","1983-10-01T00:00:00","1984-01-01T00:00:00","1984-04-01T00:00:00","1984-07-01T00:00:00","1984-10-01T00:00:00","1985-01-01T00:00:00","1985-04-01T00:00:00","1985-07-01T00:00:00","1985-10-01T00:00:00","1986-01-01T00:00:00","1986-04-01T00:00:00","1986-07-01T00:00:00","1986-10-01T00:00:00","1987-01-01T00:00:00","1987-04-01T00:00:00","1987-07-01T00:00:00","1987-10-01T00:00:00","1988-01-01T00:00:00","1988-04-01T00:00:00","1988-07-01T00:00:00","1988-10-01T00:00:00","1989-01-01T00:00:00","1989-04-01T00:00:00","1989-07-01T00:00:00","1989-10-01T00:00:00","1990-01-01T00:00:00","1990-04-01T00:00:00","1990-07-01T00:00:00","1990-10-01T00:00:00","1991-01-01T00:00:00","1991-04-01T00:00:00","1991-07-01T00:00:00","1991-10-01T00:00:00","1992-01-01T00:00:00","1992-04-01T00:00:00","1992-07-01T00:00:00","1992-10-01T00:00:00","1993-01-01T00:00:00","1993-04-01T00:00:00","1993-07-01T00:00:00","1993-10-01T00:00:00","1994-01-01T00:00:00","1994-04-01T00:00:00","1994-07-01T00:00:00","1994-10-01T00:00:00","1995-01-01T00:00:00","1995-04-01T00:00:00","1995-07-01T00:00:00","1995-10-01T00:00:00","1996-01-01T00:00:00","1996-04-01T00:00:00","1996-07-01T00:00:00","1996-10-01T00:00:00","1997-01-01T00:00:00","1997-04-01T00:00:00","1997-07-01T00:00:00","1997-10-01T00:00:00","1998-01-01T00:00:00","1998-04-01T00:00:00","1998-07-01T00:00:00","1998-10-01T00:00:00","1999-01-01T00:00:00","1999-04-01T00:00:00","1999-07-01T00:00:00","1999-10-01T00:00:00","2000-01-01T00:00:00","2000-04-01T00:00:00","2000-07-01T00:00:00","2000-10-01T00:00:00","2001-01-01T00:00:00","2001-04-01T00:00:00","2001-07-01T00:00:00","2001-10-01T00:00:00","2002-01-01T00:00:00","2002-04-01T00:00:00","2002-07-01T00:00:00","2002-10-01T00:00:00","2003-01-01T00:00:00","2003-04-01T00:00:00","2003-07-01T00:00:00","2003-10-01T00:00:00","2004-01-01T00:00:00","2004-04-01T00:00:00","2004-07-01T00:00:00","2004-10-01T00:00:00","2005-01-01T00:00:00","2005-04-01T00:00:00","2005-07-01T00:00:00","2005-10-01T00:00:00","2006-01-01T00: ...

# %%
fred_api_key = 'dxxxxxxxxxxxxxxxxxxx'

def get_fred_series_data(api_key, series):
    url = "https://api.stlouisfed.org/geofred/series/data?series_id={0}&api_key={1}&file_type=json".format(series, api_key)
    response = requests.request("GET", url)
    return response

def transform_series_response(response):
    latest_date = list(response.json()['meta']['data'].keys())[0]
    return pd.DataFrame(response.json()['meta']['data'][latest_date])

# %%
response = get_fred_series_data(fred_api_key, series)

df_all_series_ids = transform_series_response(response)

# %%
df_all_series_ids
# Out:
#                   region code     value   series_id
# 0                 Turkey   TR  259.4377  QTRR628BIS
# 1              Singapore   SG  112.9369  QSGR628BIS
# 2                  Japan   JP  120.8431  QJPR628BIS
# 3                 Brazil   BR   86.7565  QBRR628BIS
# 4           South Africa   ZA   89.4377  QZAR628BIS
# 5              Lithuania   LT  157.5566  QLTR628BIS
# 6                Germany   DE  130.4116  QDER628BIS
# 7         United Kingdom   GB  115.4043  QGBR628BIS
# 8               Slovakia   SK  118.3797  QSKR628BIS
# 9                 Poland   PL  109.0124  QPLR628BIS
# 10           New Zealand   NZ  168.6544  QNZR628BIS
# 11              Slovenia   SI  118.3616  QSIR628BIS
# 12                France   FR  106.1747  QFRR628BIS
# 13     Republic of Korea   KR  109.9962  QKRR628BIS
# 14  United Arab Emirates   AE  131.2541  QAER628BIS
# 15                Latvia   LV  155.2240  QLVR628BIS
# 16                Serbia   RS  105.8900  QRSR628BIS
# 17               Denmark   DK  119.7717  QDKR628BIS
# 18               Belgium   BE  108.4652  QBER628BIS
# 19               Morocco   MA   81.0996  QMAR628BIS
# 20         United States   US  159.5899  QUSR628BIS
# 21                Norway   NO  130.6869  QNOR628BIS
# 22                 Italy   IT   71.3728  QITR628BIS
# 23               Ireland   IE  126.3600  QIER628BIS
# 24              Malaysia   MY  161.1599  QMYR628BIS
# 25              Bulgaria   BG  118.2167  QBGR628BIS
# 26           Netherlands   NL  117.6458  QNLR628BIS
# 27        Czech Republic   CZ  139.1280  QCZR628BIS
# 28               Estonia   EE  185.4199  QEER628BIS
# 29                 Spain   ES   86.9031  QESR628BIS
# 30                 Malta   MT  129.4027  QMTR628BIS
# 31                  Peru   PE  110.9476  QPER628BIS
# 32             Indonesia   ID   96.9912  QIDR628BIS
# 33                Canada   CA  165.1556  QCAR628BIS
# 34                Sweden   SE  133.3813  QSER628BIS
# 35              Colombia   CO  136.0388  QCOR628BIS
# 36               Austria   AT  146.6119  QATR628BIS
# 37             Hong Kong   HK  156.7415  QHKR628BIS
# 38                Cyprus   CY   77.5011  QCYR628BIS
# 39                Mexico   MX  139.7483  QMXR628BIS
# 40                Israel   IL  178.3917  QILR628BIS
# 41             Australia   AU  128.4883  QAUR628BIS
# 42                Greece   GR   85.9812  QGRR628BIS
# 43               Croatia   HR  119.5504  QHRR628BIS
# 44           Switzerland   CH  151.0030  QCHR628BIS
# 45               Hungary   HU  159.5183  QHUR628BIS
# 46            Luxembourg   LU  156.7248  QLUR628BIS

# %%
df_all_series_ids.region.unique()
# Out:
# array(['Turkey', 'Singapore', 'Japan', 'Brazil', 'South Africa',
#        'Lithuania', 'Germany', 'United Kingdom', 'Slovakia', 'Poland',
#        'New Zealand', 'Slovenia', 'France', 'Republic of Korea',
#        'United Arab Emirates', 'Latvia', 'Serbia', 'Denmark', 'Belgium',
#        'Morocco', 'United States', 'Norway', 'Italy', 'Ireland',
#        'Malaysia', 'Bulgaria', 'Netherlands', 'Czech Republic', 'Estonia',
#        'Spain', 'Malta', 'Peru', 'Indonesia', 'Canada', 'Sweden',
#        'Colombia', 'Austria', 'Hong Kong', 'Cyprus', 'Mexico', 'Israel',
#        'Australia', 'Greece', 'Croatia', 'Switzerland', 'Hungary',
#        'Luxembourg'], dtype=object)

# %%
df_g7 = df_all_series_ids.loc[(df_all_series_ids['region'] == 'Canada') | (df_all_series_ids['region'] == 'France') | (df_all_series_ids['region'] == 'Germany') | (df_all_series_ids['region'] == 'Italy') | (df_all_series_ids['region'] == 'Japan') | (df_all_series_ids['region'] == 'United Kingdom') | (df_all_series_ids['region'] == 'United States')]

# %%
df_g7
# Out:
#             region code     value   series_id
# 2            Japan   JP  120.8431  QJPR628BIS
# 6          Germany   DE  130.4116  QDER628BIS
# 7   United Kingdom   GB  115.4043  QGBR628BIS
# 12          France   FR  106.1747  QFRR628BIS
# 20   United States   US  159.5899  QUSR628BIS
# 22           Italy   IT   71.3728  QITR628BIS
# 33          Canada   CA  165.1556  QCAR628BIS

# %%
g7_list = df_g7['series_id'].tolist()

# %%
g7_list
# Out:
# ['QJPR628BIS',
#  'QDER628BIS',
#  'QGBR628BIS',
#  'QFRR628BIS',
#  'QUSR628BIS',
#  'QITR628BIS',
#  'QCAR628BIS']

# %%
start_date = '1970-01-01'
end_date = '2021-10-01'

df_g7 = get_data(series_list = g7_list,
                          start_date = start_date,
                          end_date = end_date)

# %%
df_g7
# Out:
#           DATE  QJPR628BIS  QDER628BIS  QGBR628BIS  QFRR628BIS  QUSR628BIS  \
# 0   1970-01-01     97.4678    118.9989     22.4096     40.5273     60.8572
# 1   1970-04-01    100.5088    123.2700     21.8645     40.6816     60.2999
# 2   1970-07-01    104.7421    124.3390     22.7399     41.1835     60.5691
# 3   1970-10-01    105.9025    124.7133     22.2637     40.6347     60.5135
# 4   1971-01-01    108.3291    125.7255     22.2249     40.0722     61.6985
# ..         ...         ...         ...         ...         ...         ...
# 203 2020-10-01    108.8926    149.3463    118.3866    108.1316    143.1810
# 204 2021-01-01    112.5230    148.7445    120.6621    108.3302    146.1633
# 205 2021-04-01    114.1395    152.7808    121.2147    109.5674    149.7060
# 206 2021-07-01    116.4490    157.7869    122.3296    112.2212    153.8053
# 207 2021-10-01    115.7422    160.5950    122.1418    112.5060    157.5557
#
#      QITR628BIS  QCAR628BIS
# 0       40.7872     37.8580
# 1       41.0527     37.6715
# 2       40.6774     37.6729
# 3       40.4478     38.9418
# 4       39.4169     39.0597
# ..          ...         ...
# 203     76.8214    165.7664
# 204     76.9408    168.1633
# 205     77.7337    176.8375
# 206     77.9912    178.5126
# 207     77.1591    180.3430
#
# [208 rows x 8 columns]

# %%
df_g7_melt = pd.melt(df_g7, id_vars = ['DATE'], value_vars = g7_list, var_name = 'SERIES_ID', value_name = 'VALUE')

# %%
df_g7_melt
# Out:
#            DATE   SERIES_ID     VALUE
# 0    1970-01-01  QJPR628BIS   97.4678
# 1    1970-04-01  QJPR628BIS  100.5088
# 2    1970-07-01  QJPR628BIS  104.7421
# 3    1970-10-01  QJPR628BIS  105.9025
# 4    1971-01-01  QJPR628BIS  108.3291
# ...         ...         ...       ...
# 1451 2020-10-01  QCAR628BIS  165.7664
# 1452 2021-01-01  QCAR628BIS  168.1633
# 1453 2021-04-01  QCAR628BIS  176.8375
# 1454 2021-07-01  QCAR628BIS  178.5126
# 1455 2021-10-01  QCAR628BIS  180.3430
#
# [1456 rows x 3 columns]

# %%
countries = {'US':'United States', 'GB':'United Kingdom', 'FR':'France', 'CA':'Canada', 'DE':'Germany', 'JP':'Japan', 'IT':'Italy'}

def check_country(x):
    for country in countries:
        if country.lower() in x.lower():
            return countries[country]
    return ''

df_g7_melt['COUNTRY'] = df_g7_melt['SERIES_ID'].map(lambda x: check_country(x))

# %%
df_g7_melt
# Out:
#            DATE   SERIES_ID     VALUE COUNTRY
# 0    1970-01-01  QJPR628BIS   97.4678   Japan
